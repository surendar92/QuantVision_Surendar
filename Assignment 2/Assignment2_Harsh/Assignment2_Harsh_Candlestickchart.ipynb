# %%
import yfinance as yf
import plotly as go
import plotly.graph_objects as py

# %%
df=yf.download(tickers="TCS.NS",period="6mo",interval="1d")
# Out:
# /tmp/ipython-input-745775101.py:1: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2025-06-12  3409.867188  3450.080228  3398.945127  3447.300019  4060134
# 2025-06-13  3421.285645  3426.051683  3369.157630  3369.157630  2178493
# 2025-06-16  3471.527100  3484.137066  3401.923694  3415.625963  1934088
# 2025-06-17  3490.392578  3495.059228  3463.385351  3485.130083  2111940
# 2025-06-18  3426.945312  3512.931813  3418.704315  3494.165824  2696327

# %%
df.columns=["Close","High","Low","Open","Volume"]
df.head()
# Out:
#                   Close         High          Low         Open   Volume
# Date
# 2025-06-12  3409.867188  3450.080228  3398.945127  3447.300019  4060134
# 2025-06-13  3421.285645  3426.051683  3369.157630  3369.157630  2178493
# 2025-06-16  3471.527100  3484.137066  3401.923694  3415.625963  1934088
# 2025-06-17  3490.392578  3495.059228  3463.385351  3485.130083  2111940
# 2025-06-18  3426.945312  3512.931813  3418.704315  3494.165824  2696327

# %%
graph=py.Figure(data=[py.Candlestick(x=df.index,open=df["Open"],high=df["High"],low=df["Low"],close=df["Close"])])
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
graph.update_layout(xaxis_title="Date",yaxis_title="Price(INR)",title="TCS Stock Analysis using Candlestick Chart")
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from IPython.display import Image, display

display(Image(filename='/content/chart.png'))

# %%
#A Bullish Engulfing pattern was observed on October 3rd,after which the stock price moved upward,indicating a short-term bullish reversal.
#After 3rd October Price moved from ~₹2900 to above ₹3100 in the following weeks.
#This confirms the pattern as a successful bullish reversal signal.

# %%
#On 18th June a bearish engulfing was observed as there was a decline in the prices observed in candles on 17th and 18th as open price was greate than close price
#which confirms a bearish candle.

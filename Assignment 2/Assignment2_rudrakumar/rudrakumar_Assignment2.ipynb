# %%
# !pip install yfinance plotly

# %%
import yfinance as yf
from datetime import datetime, timedelta
ticker = 'NVDA'
end_date = datetime.now()
start_date = end_date - timedelta(days=6*30)
stock_data = yf.download(ticker, start=start_date, end=end_date)
print(stock_data.head())
# Out:
# /tmp/ipython-input-3136708946.py:6: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            NVDA        NVDA        NVDA        NVDA       NVDA
# Date
# 2025-06-16  144.673782  146.163606  143.183944  143.333936  183133700
# 2025-06-17  144.103836  145.203719  143.763878  144.473805  139108000
# 2025-06-18  145.463684  145.633663  143.103948  143.993848  161494100
# 2025-06-20  143.833878  146.183605  142.634000  145.433689  242956200
# 2025-06-23  144.153839  144.763771  142.014080  142.484028  154308900

# %%
import plotly.graph_objects as go
stock_data_reset = stock_data.reset_index()
fig = go.Figure(
    data=[
        go.Candlestick(
            x=stock_data_reset['Date'],
            open=stock_data_reset[('Open', 'NVDA')],
            high=stock_data_reset[('High', 'NVDA')],
            low=stock_data_reset[('Low', 'NVDA')],
            close=stock_data_reset[('Close', 'NVDA')],
            name='candlestick'
        )
    ]
)
fig.update_layout(
    title=f'candlestick-chart',
    xaxis_title='date',
    yaxis_title='price',
    xaxis_rangeslider_visible=False
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# the pattern occured on oct 31 to 3 november 1 2025 see chart the pattern started there
# i think it is the bearish engulfing pattern
# the price is going down after the pattern is seen

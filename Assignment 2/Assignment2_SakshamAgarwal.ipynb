# %%
import yfinance as yf
import plotly.graph_objects as go

# %%
ticker_symbol='ADANIENT.NS'
ticker=yf.Ticker(ticker_symbol)

# %%
historical_data=ticker.history(period='6mo',interval='1d')
print(f'Historical Data for {ticker_symbol}')
print(historical_data)
# Out:
# Historical Data for ADANIENT.NS
#                                   Open         High          Low        Close  \
# Date
# 2025-06-11 00:00:00+05:30  2628.696766  2629.596222  2561.830014  2579.920898
# 2025-06-12 00:00:00+05:30  2590.215815  2600.510760  2528.746291  2542.439453
# 2025-06-13 00:00:00+05:30  2498.000000  2516.000000  2460.000000  2507.899902
# 2025-06-16 00:00:00+05:30  2500.000000  2563.300049  2462.000000  2544.000000
# 2025-06-17 00:00:00+05:30  2535.000000  2539.600098  2479.000000  2488.500000
# ...                                ...          ...          ...          ...
# 2025-12-05 00:00:00+05:30  2217.899902  2268.600098  2202.899902  2265.399902
# 2025-12-08 00:00:00+05:30  2265.399902  2270.399902  2205.000000  2216.199951
# 2025-12-09 00:00:00+05:30  2216.199951  2257.000000  2178.399902  2245.199951
# 2025-12-10 00:00:00+05:30  2255.800049  2267.500000  2204.100098  2211.600098
# ...

# %%
fig=go.Figure(data=[go.Candlestick(x=historical_data.index,
                                    open=historical_data['Open'],
                                    high=historical_data['High'],
                                    low=historical_data['Low'],
                                    close=historical_data['Close'])])
fig.update_layout(title='Candlestick Chart for ADANI ENTERPRISES')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 28th October, 2025
# Doji Candlestick
# Price went up
